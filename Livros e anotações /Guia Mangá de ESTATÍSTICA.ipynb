# %% [markdown]
# # **Guia Mangá de *ESTATÍSTICA***
#
# O **Guia Mangá de Estatística** é uma abordagem única e divertida para aprender estatística usando o formato de mangá, o famoso estilo de quadrinhos japonês. Este livro é parte de uma série que utiliza personagens e histórias envolventes para ensinar conceitos complexos de maneira acessível e visual. Ele é voltado especialmente para quem está começando ou para aqueles que acham estatística um pouco difícil de entender pelos métodos tradicionais.
#
# ### Conteúdo do Guia
#
# 1. **Introdução aos Conceitos Básicos**:
#    - O livro começa com uma visão geral da estatística, explicando o que é, por que é importante e como é usada em várias áreas, como ciência, negócios e estudos sociais.
#    - Aborda conceitos iniciais, como **população**, **amostra**, **variáveis** e a importância da coleta de dados.
#
# 2. **Tipos de Dados e Medidas**:
#    - Explica a diferença entre **dados qualitativos** e **dados quantitativos**, além das escalas de medição (nominal, ordinal, intervalar e razão).
#    - Apresenta as principais medidas descritivas, como média, mediana, moda, variância e desvio padrão.
#
# 3. **Distribuições e Probabilidade**:
#    - O guia apresenta o conceito de **distribuições de dados**, como a distribuição normal, e explica o papel da probabilidade na estatística.
#    - Utiliza exemplos e histórias com os personagens para facilitar a compreensão desses temas abstratos.
#
# 4. **Inferência Estatística**:
#    - O livro também cobre temas como **intervalos de confiança** e **testes de hipóteses**, ajudando o leitor a entender como tirar conclusões sobre uma população com base em uma amostra.
#    - Ensina a interpretar os resultados estatísticos, abordando conceitos como o **valor p** e o nível de significância.
#
# 5. **Análise de Regressão e Correlação**:
#    - Explora a relação entre variáveis e como prever resultados usando a **regressão linear**.
#    - Explica a **correlação** e como determinar a força e direção da relação entre variáveis.
#
# ### Como o Mangá Ajuda no Aprendizado
#
# - **Visual e Narrativo**: Os personagens têm dilemas e desafios que são resolvidos por meio de conceitos estatísticos, tornando a leitura mais envolvente e prática.
# - **Simplificação de Conceitos**: Explicações são dadas em uma linguagem simples e ilustradas de forma que o leitor consiga absorver conceitos complexos com mais facilidade.
# - **Exemplos do Cotidiano**: O livro usa cenários do dia a dia, facilitando o entendimento de como a estatística se aplica ao mundo real.
#
# ### Por que Ler o Guia Mangá de Estatística?
#
# - **Ideal para Iniciantes**: É excelente para quem quer aprender estatística do zero, de maneira leve e com menos termos técnicos.
# - **Aprendizado Rápido**: As ilustrações ajudam a fixar os conceitos de forma rápida e intuitiva.
# - **Divertido e Informativo**: Ao contrário dos livros didáticos tradicionais, o formato de mangá faz com que o aprendizado seja mais agradável e memorável.
#
# Esse guia é uma ferramenta valiosa para estudantes, profissionais ou qualquer pessoa que queira entender estatística sem se sobrecarregar com matemática complexa.

# %% [markdown]
# ### **Estatística** é o estudo de dados com o objetivo de compreender, analisar e tirar conclusões sobre uma população. Ao coletar e analisar dados de uma amostra representativa, a estatística ajuda a fazer previsões e inferências sobre a população como um todo.
#
# **População**: Refere-se ao conjunto completo de indivíduos ou elementos sobre os quais queremos obter informações. A população pode ser muito grande (por exemplo, todos os habitantes de um país) ou específica (por exemplo, todos os funcionários de uma empresa).
#
# **Amostra**: É um subconjunto da população, selecionado para representar a totalidade. A amostra é usada para fazer inferências sobre a população, com a expectativa de que os resultados sejam aplicáveis à população geral, desde que a amostra seja representativa e bem escolhida.

# %% [markdown]
# # 1. **Tipos de Dados em Estatística:**
#
# 1. **Dados Qualitativos/Categóricos**: São dados que descrevem qualidades ou categorias e não podem ser medidos numericamente. Eles são usados para identificar atributos ou características de uma amostra ou população.
#    - **Exemplo**: Cor dos olhos (azul, verde, castanho), gênero (feminino, masculino), cidade de origem.
#
# 2. **Dados Quantitativos/Numericos**: São dados que podem ser medidos e expressos em números. Eles representam quantidades e permitem cálculos matemáticos.
#    - **Exemplo**: Idade, altura, peso, salário.
#
# ### Subdivisões:
# - **Qualitativos**:
#    - **Nominal**: Categorias sem ordem lógica (exemplo: cores).
#    - **Ordinal**: Categorias com uma ordem (exemplo: níveis de escolaridade).
# - **Quantitativos**:
#    - **Discreto**: Valores contáveis, sem frações (exemplo: número de filhos).
#    - **Contínuo**: Pode assumir qualquer valor dentro de um intervalo (exemplo: altura, peso).

# %% [markdown]
# ## **Como as respostas de múltipla escolhas são administrdas na prática**
#
# Na prática, as respostas de múltipla escolha são administradas por meio de sistemas que organizam, analisam e armazenam os dados coletados de forma eficiente. Aqui estão os principais passos no processo de administração dessas respostas:
#
# 1. **Desenvolvimento do Questionário**:
#    - A primeira etapa envolve a criação de perguntas de múltipla escolha que sejam claras e relevantes para o objetivo da pesquisa.
#    - As opções devem cobrir as possíveis respostas sem causar confusão e, quando possível, incluir uma opção “Outro” ou “Nenhum dos anteriores”.
#
# 2. **Coleta de Respostas**:
#    - A coleta pode ser feita via plataformas online (como Google Forms, SurveyMonkey, Typeform) ou em papel, dependendo do público-alvo e dos recursos disponíveis.
#    - Ferramentas digitais facilitam a administração e organização dos dados automaticamente.
#
# 3. **Codificação das Respostas**:
#    - Cada resposta de múltipla escolha é associada a um valor numérico ou categoria, o que facilita o processamento e a análise estatística.
#    - Exemplo: “Sim” pode ser codificado como 1 e “Não” como 0.
#
# 4. **Armazenamento dos Dados**:
#    - As respostas são armazenadas em um banco de dados ou em planilhas (como Excel), o que permite a organização das respostas por categoria.
#    - Cada resposta de um participante é registrada como uma linha de dados, com cada pergunta representada em uma coluna.
#
# 5. **Análise das Respostas**:
#    - Ferramentas estatísticas e de visualização de dados (como Excel, SPSS, Power BI) são usadas para analisar as respostas.
#    - Métricas como frequência de respostas, porcentagens, médias e gráficos ajudam a interpretar os dados.
#
# 6. **Relatório e Interpretação dos Resultados**:
#    - Os resultados das respostas de múltipla escolha são interpretados e apresentados em relatórios para identificar padrões, preferências e tendências.
#    - Os insights gerados podem ajudar na tomada de decisões ou direcionamento de futuras pesquisas.
#
# Esse processo permite que os dados de múltipla escolha sejam analisados de forma rápida e eficaz, fornecendo uma visão clara das preferências ou opiniões da população pesquisada.

# %% [markdown]
# ## **Exercícios**
# ![image.png](attachment:image.png)
#
#
# **Resposta**: Os dados "Tipo sanguíneo" e "Opinião sobre a bebida energética X" são dados categóricos, e os dados "Temperatura ideal do ar condicionado (ºC)" e "Recorde em corrida de 100 metros rasos (segundos)" são dados númericos.

# %% [markdown]
# **RESUMO**
# * DADOS SÃO CLASSIFICADOS COMO DADOS CATEGÓRICOS OU DADOS NÚMERICOS.
# * ALGUNS DADOS, COMO "MUITO DIVERTIDA" OU "MUITO CHATA". SÃO DADOS TEORICAMENTE CATEGÓRICOS. NO ENTANTO, NA PRÁTICA, É POSSÍVEL TRATÁ-LOS COMO DADOS NÚMERICOS.

# %% [markdown]
# # 2. **A essência dos Dados Numéricos**
#
# Os dados numéricos são fundamentais em estatística, pois nos permitem descrever, organizar e interpretar informações quantitativas, sendo essenciais tanto para **estatística descritiva** quanto para **inferência estatística**.
#
# #### 1. Tabela de Distribuição de Frequência e Histogramas
#    - **Classe**: Intervalos em que os dados numéricos são agrupados, facilitando a visualização da distribuição dos valores.
#    - **Ponto Médio**: Representa o valor central de cada classe, calculado pela média dos limites inferior e superior da classe.
#    - **Frequência**: Número de ocorrências de dados dentro de cada classe.
#    - **Porcentagem**: Representa a frequência relativa em cada classe, expressa em porcentagem em relação ao total de dados.
#
#    A tabela de distribuição de frequência é frequentemente acompanhada de um **histograma**, que é um gráfico de barras que mostra a frequência ou a porcentagem dos dados dentro de cada classe, facilitando a visualização da distribuição dos dados.
#
# #### 2. Média (Valor Médio)
#    - A **média** é a soma de todos os valores dividida pelo número total de valores. Ela representa o valor central ou "ponto de equilíbrio" dos dados e é uma medida muito utilizada, embora seja sensível a valores extremos (outliers).
#
# #### 3. Mediana
#    - A **mediana** é o valor que divide o conjunto de dados em duas partes iguais quando os dados estão ordenados. Se o número de observações for ímpar, a mediana é o valor central; se for par, é a média dos dois valores centrais. A mediana é menos sensível a outliers e oferece uma visão robusta do centro dos dados.
#
# #### 4. Desvio Padrão
#    - O **desvio padrão** mede a dispersão dos dados em torno da média. Ele indica o quanto os dados variam em relação ao valor médio. Um desvio padrão alto indica maior variabilidade, enquanto um desvio padrão baixo indica que os dados estão mais próximos da média.
#
# #### 5. Intervalo de Classe de uma Tabela de Frequência
#    - O **intervalo de classe** é a diferença entre o limite superior e o limite inferior de uma classe. Ele define a largura de cada classe e é importante para a construção de histogramas e para entender a distribuição dos dados dentro de cada classe.
#
# #### 6. Inferência Estatística e Estatística Descritiva
#    - **Estatística Descritiva**: Envolve o uso de métodos para descrever e resumir dados de forma clara e compreensível. Ferramentas como média, mediana, desvio padrão e histogramas são usadas para fornecer uma visão geral dos dados.
#    - **Inferência Estatística**: Refere-se ao uso de dados de uma amostra para fazer conclusões sobre uma população. Isso inclui a construção de intervalos de confiança e a realização de testes de hipóteses para avaliar a validade de afirmações sobre a população com base na amostra.
#
# a análise de dados numéricos nos permite transformar grandes volumes de dados em insights significativos, ajudando na tomada de decisões informadas em várias áreas.

# %% [markdown]
# ## **Exercícios**
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ### Resultados
#
# - **Média**: 19,2 segundos
# - **Mediana**: 18,7 segundos
# - **Desvio Padrão**: aproximadamente 2,01 segundos

# %%
! pip install pandas
! pip install numpy

import pandas as pd
import numpy as np

# %%
corrida_alunas = {
    'Nome': ['Sra. A', 'Sra. B', 'Sra. C', 'Sra. D', 'Sra. E'],
    'Corrida de 100m (segundos)': [16.3, 22.4, 18.5, 18.7, 20.1],
}
df_corrida = pd.DataFrame(corrida_alunas)

display (df_corrida)
# Out:
#      Nome  Corrida de 100m (segundos)
# 0  Sra. A                        16.3
# 1  Sra. B                        22.4
# 2  Sra. C                        18.5
# 3  Sra. D                        18.7
# 4  Sra. E                        20.1

# %%
print(df_corrida.dtypes)
# Out:
# Nome                           object
# Corrida de 100m (segundos)    float64
# dtype: object

# %%
# Calcular a média, mediana e desvio padrão para a coluna numérica 'Corrida de 100m (segundos)'
media = np.mean(df_corrida['Corrida de 100m (segundos)'])
mediana = np.median(df_corrida['Corrida de 100m (segundos)'])
desvio_padrao = np.std(df_corrida['Corrida de 100m (segundos)'])

print(f'Média: {media:.2f} segundos')
print(f'Mediana: {mediana:.2f} segundos')
print(f'Desvio Padrão: {desvio_padrao:.2f} segundos')
# Out:
# Média: 19.20 segundos
# Mediana: 18.70 segundos
# Desvio Padrão: 2.01 segundos
